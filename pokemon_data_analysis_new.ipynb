# %%
import pandas as pd
import numpy as np
import glob
import os
from scipy.stats import zscore
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Tasks to clean:
#     - Demographics -- DONE
#     - Expertise Survey -- DONE
#     - Expertise Survey 2 (games played) -- DONE
#     - Pokemon Name Task -- DONE
#     - Visual Task -- DONE
#         - Block 1 -- DONE
#         - Block 2 -- DONE
#     - Auditory Task -- DONE
#         - Block 1 -- DONE
#         - Block 2 -- DONE
#     - Pattern Comparison Task -- DONE
#         - Block 1 -- DONE
#         - Block 2 -- DONE
#     - Lettersets - DONE
#     - Number Series - DONE

# %% [markdown]
# ### Need to return to this once accuracies are calculated to do the same for reaction times.

# %% [markdown]
# ## Open the files and join them together

# %%
file_path = ("./CAPE LOCAL/full_data/")

# %%
all_files = glob.glob(os.path.join(file_path, "*.csv"))

df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

# %%
# Add the participant ID to all rows.
df['participant_id'] = df['participant_id'].ffill()

# %%
# time_render
# time_end
# time_end - time_render = reactio_time
# np.where will be used to get the reaction time for a given task

# average over all auditory
# average over pokemon auditory
# average over animal auditory
# pokemon over all visual
# average over pokemon visual
# average over animal visual

# %% [markdown]
# ## Clean the expertise survey

# %%
df['age_first_movie'] = np.where(df['sender'] == 'Expertise Survey',
                                 df['age'],
                                 np.nan)

# %%
# Join the data from the google form csv with the same column names.

expertise_df = pd.read_csv('Pokemon Expertise Survey.csv')
expertise_df.drop(columns=['Username'], inplace=True)

expertise_df.columns = ['Timestamp', 'participant_id', 'pokemon_interest', 'pokemon_knowledge',
                        'watched_movies_tv', 'movie_tv_multiple', 'movie_tv_number', 'age_first_movie',
                        'played_pokemon_games', 'played_multiple_times', 'played_number_times', 
                        'years_since_first_game', 'favorite_pokemon', 'fav_gen', 'follow_socials',
                        'engage_weekly', 'collect_trading_cards', 'years_collecting_cards',
                        'play_competitively', 'years_play_competitively', 'all_games_played']

# %%
expertise_df['all_games_played'] = expertise_df['all_games_played'].apply(lambda x: x.replace(" ", "_"))
expertise_df['all_games_played'] = expertise_df['all_games_played'].apply(lambda x: x.split(';'))

# %%
ex_df2 = expertise_df.copy()
ex_df2.set_index('participant_id',inplace=True)
expertise_dict = ex_df2.to_dict()['all_games_played']

# %% [markdown]
# ## Clean the Name Recognition Test

# %%
mask = (df['sender'] == 'Pokémon Name Recognition Test')

for pokemon_column in ['Abra' , 'Bulbasaur' , 'Charizard' , 'Ditto',
                       'Dodrio' , 'Dragonite' , 'Eevee' , 'Electrode',
                       'goldeen' , 'Golbat' , 'Horsea' , 'Jigglypuff',
                       'Jynx' , 'Koffing' , 'Muk' , 'Pikachu',
                       'Pinsir' , 'Poliwrath' , 'Ponyta' , 'Psyduck',
                       'Scyther' , 'Seel' , 'Snorlax' , 'Staryu' , 'Tangela',
                       'Astax' , 'Birdrum' , 'Brustum' , 'Blitzbug',
                       'Crylax' , 'Dastardo' , 'Fluritzee' , 'Frogert',
                       'Fwooshy' , 'Gargooey' , 'Gumy' , 'Koaleon',
                       'Loffitoff' , 'Loopinsy' , 'Munkeezy' , 'Oxston',
                       'Postorph', 'Quix' , 'Ramstar' , 'Sheepo' , 'Spish',
                       'Tungstroy' , 'Vibeast' , 'Vitrion' , 'Yipster']:
    
    df.loc[mask, pokemon_column] = df.loc[mask, pokemon_column].fillna(value=False)

# %%
# Calculate the total correct real names and the incorrect fake names each into new columns.
df['real_names_correct'] = df['Abra'] + df['Bulbasaur'] + df['Charizard'] + df['Ditto'] \
                           + df['Dodrio'] + df['Dragonite'] + df['Eevee'] + df['Electrode'] \
                           + df['goldeen'] + df['Golbat'] + df['Horsea'] + df['Jigglypuff'] \
                           + df['Jynx'] + df['Koffing'] + df['Muk'] + df['Pikachu'] \
                           + df['Pinsir'] + df['Poliwrath'] + df['Ponyta'] + df['Psyduck'] \
                           + df['Scyther'] + df['Seel'] + df['Snorlax'] + df['Staryu'] + df['Tangela']
    
df['fake_names_incorrect'] = df['Astax'] + df['Birdrum'] + df['Brustum'] + df['Blitzbug'] \
                             + df['Crylax'] + df['Dastardo'] + df['Fluritzee'] + df['Frogert'] \
                             + df['Fwooshy'] + df['Gargooey'] + df['Gumy'] + df['Koaleon']\
                             + df['Loffitoff'] + df['Loopinsy'] + df['Munkeezy'] + df['Oxston']\
                             + df['Postorph']+ df['Quix'] + df['Ramstar'] + df['Sheepo'] + df['Spish']\
                             + df['Tungstroy'] + df['Vibeast'] + df['Vitrion'] + df['Yipster']

# %% [markdown]
# ## Clean the trivia questions

# %%
# Score the trivia questions - compare correct answers to responded answer.

df = df.assign(trivia_correct=0)

correct_trivia_ans = ['responded_answer3', 'responded_answer1', 'responded_answer4', 'responded_answer3',
                      'responded_answer3', 'responded_answer2', 'responded_answer4', 'responded_answer4',
                      'responded_answer2', 'responded_answer1', 'responded_answer3', 'responded_answer2', 
                      'responded_answer4', 'responded_answer1', 'responded_answer2', 'responded_answer3',
                      'responded_answer2', 'responded_answer2', 'responded_answer1', 'responded_answer1',
                      'responded_answer4', 'responded_answer3', 'responded_answer1', 'responded_answer4', 
                      'responded_answer2']

for trivia_num, trivia_ans in list(zip(range(1,26), correct_trivia_ans)):
    
    df['trivia_correct'] = np.where(( (df["sender"] == 'Knowledge Question Screen') \
                                     & (df["question_num"] == float(trivia_num)) \
                                     & (df['response'] == trivia_ans)) \
                                     | (df['trivia_correct'] == 1),
                                                          1,
                                                          0)

# %%
## Riley Change 2026-02-03: Added reaction time

df['trivia_reaction_time'] = (np.where(df['trivia_correct'] == 1,
                                       (df['time_end'] - df['time_render'])/1000,
                                       np.nan))

# %% [markdown]
# ## Clean the visual task

# %%
# Score the visual task responses. 

df = df.assign(visual_correct=0)

df['prev_screen'] = df["sender"].shift(1)
df['two_prev_screen'] = df["sender"].shift(2)
df['three_prev_screen'] = df["sender"].shift(3)
df['next_screen'] = df["sender"].shift(-1)

correct_visual_ans = {'131.png':'box1', '12.png':'box5', '136.png':'box1', '34.png':'box2', '11.png':'box5', 
                      'horse_4.jpg':'box4', '93.png':'box2', 'cricket_4.jpg':'box4', 'frog_2.jpg':'box2', 
                      '42.png':'box5', '85.png':'box5', '4.png':'box2', '13.png':'box6', '99.png':'box4',
                       '10.png':'box6', '50.png':'box5', '38.png':'box4', '76.png':'box6', '41.png':'box2', 
                      '23.png':'box5', '27.png':'box5', '62.png':'box3', '96.png':'box5', '138.png':'box5', 
                      '84.png':'box5', 'pig_3.jpg':'box1', '24.png':'box2', 'monkey_5.jpg':'box5',
                      'bee_6.jpg':'box1', '151.png':'box2', '106.png':'box6', '112.png':'box4', 
                      '98.png':'box4', '139.png':'box1', '89.png':'box6', '21.png':'box1', 
                      'birds_2.jpg':'box1', 'chicken_1.jpg':'box6', '2.png':'box3', '48.png':'box2', 
                      '55.png':'box2', '52.png':'box2', 'duck_8.jpg':'box3', '135.png':'box3', 
                      'sheep_2.jpg':'box4', '101.png':'box2', '77.png':'box6', '122.png':'box4', 
                      '58.png':'box2', '71.png':'box5', 
                      'dog_5.jpg':'box3', '20.png':'box1', '3.png':'box5', '69.png':'box3', '111.png':'box2', 
                      '110.png':'box3', '142.png':'box1', 'lion_2.jpg':'box1', '43.png':'box1', 
                      '32.png':'box3', 'elephant_5.jpg':'box4', '121.png':'box5', '127.png':'box6', 
                      'turkey_6.jpg':'box5', 'bear_2.jpg':'box1', '36.png':'box3', 'owl_4.jpg':'box4', 
                      'cat_1.jpg':'box2', '17.png':'box5', '134.png':'box1', '130.png':'box3', 
                      '107.png':'box2', '9.png':'box1', '63.png':'box3', '5.png':'box2', '49.png':'box3', 
                      '1.png':'box4', '125.png':'box2', 'cow_3.jpg':'box5', '88.png':'box1', '26.png':'box2',
                       '61.png':'box4', '145.png':'box6', '7.png':'box1', '72.png':'box4', '124.png':'box5',
                       'donkey_4.jpg':'box3', '81.png':'box4', '129.png':'box3', 'tiger_3.jpg':'box1', 
                      '146.png':'box3', '116.png':'box2', '140.png':'box3', '56.png':'box5', '25.png':'box2',
                       '150.png':'box5', '64.png':'box4', '97.png':'box4', '16.png':'box5', '113.png':'box4'}

for key, value in correct_visual_ans.items():
    
    df['visual_correct'] = np.where(( (df["sender"] == 'Response Screen') \
                                     & (df["poke_image"] == key) \
                                     & (df['response'] == value)) \
                                     | (df['visual_correct'] == 1),
                                                          1,
                                                          0)

# %%
animals_image_list = ['horse_4.jpg', 'cricket_4.jpg', 'frog_2.jpg', 'pig_3.jpg', 'monkey_5.jpg',
                      'bee_6.jpg', 'birds_2.jpg', 'chicken_1.jpg', 'duck_8.jpg', 'sheep_2.jpg',
                      'dog_5.jpg', 'lion_2.jpg', 'elephant_5.jpg', 'turkey_6.jpg', 'bear_2.jpg',
                      'owl_4.jpg','cat_1.jpg', 'cow_3.jpg', 'donkey_4.jpg', 'tiger_3.jpg']

# %%
pokemon_image_list = ['131.png', '12.png', '136.png', '34.png', '11.png', '93.png', '42.png', '85.png',
                      '4.png', '13.png', '99.png', '10.png', '50.png', '38.png', '76.png', '41.png',
                      '23.png', '27.png', '62.png', '96.png', '138.png', '84.png', '24.png', '21.png',
                      '89.png', '139.png', '98.png', '112.png', '106.png', '151.png', '2.png', '48.png',
                      '55.png','52.png', '135.png', '101.png', '77.png', '122.png', '58.png', '71.png',
                      '20.png','3.png','69.png','111.png','110.png','142.png', '43.png', '32.png',
                      '121.png','127.png', '36.png','17.png','134.png','130.png','107.png','9.png',
                      '63.png','5.png','49.png','1.png','125.png', '88.png', '26.png','61.png','145.png',
                      '7.png','72.png','124.png','81.png','129.png','146.png','116.png','140.png',
                      '56.png','25.png','150.png','64.png','97.png','16.png','113.png']

# %%
## Riley Change 2026-02-03: Changed np.nan to None due to error

df['visual_trial_type'] = np.where( df['poke_image'].isin(animals_image_list),
                                    'animal trial',
                                    np.where(df['poke_image'].isin(pokemon_image_list),
                                             'pokemon trial',
                                             None))

# %%
# Get the blocks for the visual task.

df['visual_block'] = np.where( (df["sender"] == 'Response Screen') \
                               & (df["prev_screen"] == 'Pokemon Image Screen') \
                               & (df['response'].notnull()) \
                               & (df["three_prev_screen"] == 'Visual Instructions'),
                             1,
                                 np.where( (df["sender"] == 'Response Screen') \
                                   & (df["prev_screen"] == 'Pokemon Image Screen') \
                                   & (df['response'].notnull()) \
                                   & (df["three_prev_screen"] == 'In between blocks instruction'),
                                       2,
                                       np.where( (df["sender"] == 'Visual Loop 2') \
                                       & (df["prev_screen"] == 'Sequence') \
#                                        & (df['response'].notnull()) \
                                       & (df["next_screen"] == 'Pokemon Auditory Instructions'),
                                         0,
                                         np.nan
                                                                      )))

# %%
df['visual_block'] = df['visual_block'].ffill()

# %%
df['visual_correct_block1'] = df[df['visual_block'] == 1]['visual_correct']
df['visual_correct_block2'] = df[df['visual_block'] == 2]['visual_correct']

# %%
df['visual_pokemon_correct_block1'] = df[(df['visual_block'] == 1) & (df['visual_trial_type'] == 'pokemon trial')]['visual_correct']
df['visual_pokemon_correct_block2'] = df[(df['visual_block'] == 2)  & (df['visual_trial_type'] == 'pokemon trial')]['visual_correct']

# %%
df['visual_animal_correct_block1'] = df[(df['visual_block'] == 1) & (df['visual_trial_type'] == 'animal trial')]['visual_correct']
df['visual_animal_correct_block2'] = df[(df['visual_block'] == 2)  & (df['visual_trial_type'] == 'animal trial')]['visual_correct']

# %%
df['pokemon_visual_correct'] = df[df['visual_trial_type'] == 'pokemon trial']['visual_correct']
df['animal_visual_correct'] = df[df['visual_trial_type'] == 'animal trial']['visual_correct']

# %%
## Riley Change 2026-02-03: Added reaction time

df['overall_visual_reaction_time'] = (np.where((df['pokemon_visual_correct'] == 1) |
                                               (df['animal_visual_correct'] == 1),
                                               (df['time_end'] - df['time_render'])/1000,
                                               np.nan))

df['pokemon_visual_reaction_time'] = (np.where(df['pokemon_visual_correct'] == 1,
                                               (df['time_end'] - df['time_render'])/1000,
                                               np.nan))

df['animal_visual_reaction_time'] = (np.where(df['animal_visual_correct'] == 1,
                                              (df['time_end'] - df['time_render'])/1000,
                                              np.nan))

# %% [markdown]
# ## Clean the auditory task

# %%
# Score the auditory task responses. 

df['auditory_correct'] = np.where(( (df["sender"] == 'Response Screen') \
                                     & (df["prev_screen"] == 'Pokemon Audio Screen') \
                                     & (df['response'].str.endswith('_correct'))), \
                                                          1,
                                                          0)

# %%
auditory_trial_list = [str(x) for x in list(range(14, 113, 2)) + list(range(115, 214, 2))]

# %%
auditory_trial_type_list = ['pokemon trial', 'pokemon trial', 'pokemon trial', 'pokemon trial', 'pokemon trial',
                            'animal trial', 'animal trial', 'pokemon trial','pokemon trial','pokemon trial',
                            'animal trial', 'pokemon trial', 'pokemon trial', 'pokemon trial', 'pokemon trial',
                            'pokemon trial', 'animal trial', 'pokemon trial', 'pokemon trial','pokemon trial',
                            'pokemon trial', 'pokemon trial', 'pokemon trial', 'pokemon trial', 'pokemon trial',
                            'pokemon trial', 'pokemon trial', 'animal trial', 'pokemon trial', 'pokemon trial',
                            'animal trial', 'pokemon trial', 'pokemon trial', 'pokemon trial', 'pokemon trial',
                            'pokemon trial', 'animal trial', 'pokemon trial', 'animal trial', 'pokemon trial',
                            'pokemon trial', 'pokemon trial', 'pokemon trial', 'animal trial', 'pokemon trial',
                            'pokemon trial', 'pokemon trial', 'animal trial', 'pokemon trial', 'pokemon trial',

                            'pokemon trial', 'pokemon trial', 'pokemon trial', 'pokemon trial', 'pokemon trial',
                            'pokemon trial', 'pokemon trial', 'pokemon trial', 'animal trial', 'pokemon trial',
                            'pokemon trial', 'pokemon trial', 'pokemon trial', 'animal trial', 'pokemon trial',
                            'pokemon trial', 'animal trial', 'animal trial', 'animal trial', 'pokemon trial',
                            'pokemon trial', 'pokemon trial', 'pokemon trial', 'animal trial', 'pokemon trial',
                            'pokemon trial', 'pokemon trial', 'animal trial', 'pokemon trial', 'animal trial',
                            'pokemon trial', 'pokemon trial', 'pokemon trial', 'pokemon trial', 'pokemon trial',
                            'pokemon trial', 'animal trial', 'pokemon trial', 'pokemon trial', 'pokemon trial',
                            'animal trial', 'pokemon trial', 'pokemon trial', 'pokemon trial', 'pokemon trial',
                            'pokemon trial', 'pokemon trial', 'pokemon trial', 'pokemon trial', 'pokemon trial',
                           ]

# %%
auditory_trial_type_dict = dict(zip(auditory_trial_list, auditory_trial_type_list))

# %%
df['auditory_trial_type'] = df['sender_id'].map(auditory_trial_type_dict)

# %%
# Get the blocks for the auditory task.

df['auditory_block'] = np.where( (df["sender"] == 'Response Screen') \
                               & (df["prev_screen"] == 'Pokemon Audio Screen') \
                               & (df['response'].notnull()) \
                               & (df["two_prev_screen"] == 'Pokemon Auditory Instructions'),
                             1,
                                 np.where( (df["sender"] == 'Response Screen') \
                                   & (df["prev_screen"] == 'Pokemon Audio Screen') \
                                   & (df['response'].notnull()) \
                                   & (df["two_prev_screen"] == 'In between blocks instruction'),
                                       2,
                                       np.where( (df["sender"] == 'pattern comparison instructions 1') \
                                       & (df["prev_screen"] == 'Response Screen') \
                                       & (df['response'].notnull()) \
                                       & (df["next_screen"] == 'pattern comparison instructions 2'),
                                         0,
                                         np.nan
                                                                      )))

# %%
df['auditory_block'] = df['auditory_block'].ffill()

# %%
df['auditory_correct_block1'] = df[df['auditory_block'] == 1]['auditory_correct']
df['auditory_correct_block2'] = df[df['auditory_block'] == 2]['auditory_correct']

# %%
df['auditory_pokemon_correct_block1'] = df[(df['auditory_block'] == 1) & (df['auditory_trial_type'] == 'pokemon trial')]['auditory_correct']
df['auditory_pokemon_correct_block2'] = df[(df['auditory_block'] == 2)  & (df['auditory_trial_type'] == 'pokemon trial')]['auditory_correct']

# %%
df['auditory_animal_correct_block1'] = df[(df['auditory_block'] == 1) & (df['auditory_trial_type'] == 'animal trial')]['auditory_correct']
df['auditory_animal_correct_block2'] = df[(df['auditory_block'] == 2)  & (df['auditory_trial_type'] == 'animal trial')]['auditory_correct']

# %%
df['pokemon_auditory_correct'] = df[df['auditory_trial_type'] == 'pokemon trial']['auditory_correct']
df['animal_auditory_correct'] = df[df['auditory_trial_type'] == 'animal trial']['auditory_correct']

# %%
## Riley Change 2026-02-03: Added reaction time

df['overall_auditory_reaction_time'] = (np.where((df['pokemon_auditory_correct'] == 1) |
                                                 (df['animal_auditory_correct'] == 1),
                                                 (df['time_end'] - df['time_render'])/1000,
                                                 np.nan))

df['pokemon_auditory_reaction_time'] = (np.where(df['pokemon_auditory_correct'] == 1,
                                                 (df['time_end'] - df['time_render'])/1000,
                                                 np.nan))

df['animal_auditory_reaction_time'] = (np.where(df['animal_auditory_correct'] == 1,
                                                (df['time_end'] - df['time_render'])/1000,
                                                np.nan))

# %% [markdown]
# ## Clean the pattern comparison task

# %%
# Score the pattern comparison responses. 

df = df.assign(pattern_comparison_correct=0)

correct_pattern_ans = {'stimuli_1.png':'answered_same', 'stimuli_2.png': 'answered_different', 'stimuli_3.png': 'answered_same', 
                       'stimuli_4.png': 'answered_different', 'stimuli_5.png': 'answered_same', 'stimuli_6.png': 'answered_different',
                       'stimuli_7.png': 'answered_same', 'stimuli_8.png': 'answered_different', 'stimuli_9.png': 'answered_same', 
                       'stimuli_10.png': 'answered_different', 'stimuli_11.png': 'answered_same', 'stimuli_12.png': 'answered_different',
                       'stimuli_13.png': 'answered_different', 'stimuli_14.png': 'answered_different', 'stimuli_15.png': 'answered_same',
                       'stimuli_16.png': 'answered_different', 'stimuli_17.png': 'answered_same', 'stimuli_18.png': 'answered_different',
                       'stimuli_19.png': 'answered_different', 'stimuli_20.png': 'answered_same', 'stimuli_21.png': 'answered_same',
                       'stimuli_22.png': 'answered_same', 'stimuli_23.png': 'answered_same', 'stimuli_24.png': 'answered_same',
                       'stimuli_25.png': 'answered_different', 'stimuli_26.png': 'answered_different', 'stimuli_27.png': 'answered_different',
                       'stimuli_28.png': 'answered_same', 'stimuli_29.png': 'answered_different', 'stimuli_30.png': 'answered_same',
                       'stimuli_31.png': 'answered_different', 'stimuli_32.png': 'answered_different', 'stimuli_33.png': 'answered_same', 
                       'stimuli_34.png': 'answered_same', 'stimuli_35.png': 'answered_same', 'stimuli_36.png': 'answered_same',
                       'stimuli_37.png': 'answered_different', 'stimuli_38.png': 'answered_different', 'stimuli_39.png': 'answered_same',
                       'stimuli_40.png': 'answered_same', 'stimuli_41.png': 'answered_different', 'stimuli_42.png': 'answered_different',
                       'stimuli_43.png': 'answered_same', 'stimuli_44.png': 'answered_different', 'stimuli_45.png': 'answered_different',
                       'stimuli_46.png': 'answered_different', 'stimuli_47.png': 'answered_same', 'stimuli_48.png': 'answered_same',
                       'stimuli_49.png': 'answered_same', 'stimuli_50.png': 'answered_same', 'stimuli_51.png': 'answered_same',
                       'stimuli_52.png': 'answered_different', 'stimuli_53.png': 'answered_different', 'stimuli_54.png': 'answered_different',
                       'stimuli_55.png': 'answered_same', 'stimuli_56.png': 'answered_different', 'stimuli_57.png': 'answered_different', 
                       'stimuli_58.png': 'answered_same', 'stimuli_59.png': 'answered_same', 'stimuli_60.png': 'answered_different'
                        }

df["pattern_stim1"] = df["pattern_stim1"].str.lower()

for key, value in correct_pattern_ans.items():
    
    df['pattern_comparison_correct'] = np.where(( (df["sender"] == 'Pattern Comparison Screen') \
                                     & (df["pattern_stim1"] == key) \
                                     & (df['response'] == value)) \
                                     | (df['pattern_comparison_correct'] == 1),
                                                          1,
                                                          0)

# %%
#Get the blocks for the pattern comparison task.

df['pattern_comparison_block'] = np.where( (df["sender"] == 'Pattern Comparison Screen') \
                                           & (df["prev_screen"] == 'Fixation cross') \
#                                            & (df['response'].notnull()) \
                                           & (df["three_prev_screen"] == 'pattern comparison instructions 5'),
                                         int(1),
                                             np.where( (df["sender"] == 'Pattern Comparison Screen') \
                                               & (df["prev_screen"] == 'Fixation cross') \
#                                                & (df['response'].notnull()) \
                                               & (df["three_prev_screen"] == 'pattern comparison instructions 7'),
                                                   int(2),
                                                   np.where( (df["sender"] == 'pattern comparison loop 2') \
                                                   & (df["prev_screen"] == 'Sequence') \
#                                                    & (df['response'].notnull()) \
                                                   & (df["next_screen"] == 'NumberSetInstr1'),
                                                     int(0),
                                                     np.nan
                                                                                  )))

# %%
df['pattern_comparison_block'] = df['pattern_comparison_block'].ffill()

# %%
df['pattern_comparison_correct_block1'] = df[df['pattern_comparison_block'] == 1]['pattern_comparison_correct']
df['pattern_comparison_correct_block2'] = df[df['pattern_comparison_block'] == 2]['pattern_comparison_correct']

# %% [markdown]
# ## Clean the Number series and Letterset tasks.

# %%
# Score the number series data.
df['numberset_correct'] = df[df['sender'] == 'NumberSetTrial']['correct']

# %%
# Score the letterset data.
df['letterset_correct'] = df[df['sender'] == 'Trial']['correct']

# %% [markdown]
# ## Group the data by participant ID to get a summarized row.

# %%
# [game for game in lis for lis in ]
all_games_possible = set([j for i in list(expertise_df['all_games_played']) for j in i])

# %%
# Group the data by participant ID and summarize the scores on each task.
    
agg_dict = {
                                                'gender':'first',
                                                'age':'first',
                                                'education':'first',
                                                'pokemon_interest':'first', 
                                                'pokemon_knowledge':'first',
                                                'watched_movies_tv':'first', 
                                                'movie_tv_multiple':'first', 
                                                'movie_tv_number':'first', 
                                                'age_first_movie':'first',
                                                'played_pokemon_games':'first', 
                                                'played_multiple_times':'first', 
                                                'played_number_times':'first', 
                                                'years_since_first_game':'first', 
                                                'favorite_pokemon':'first', 
                                                'fav_gen':'first', 
                                                'follow_socials':'first',
                                                'engage_weekly':'first', 
                                                'collect_trading_cards':'first', 
                                                'years_collecting_cards':'first',
                                                'play_competitively':'first', 
                                                'years_play_competitively':'first', 
#                                                 'all_games_played':'list',
                                                'real_names_correct': np.sum,
                                                'fake_names_incorrect': np.sum,
                                                'trivia_correct': np.sum,
                                                'visual_correct': np.sum,
                                                'visual_correct_block1': np.sum,
                                                'visual_correct_block2': np.sum,
                                                'pokemon_visual_correct': np.sum,
                                                'animal_visual_correct': np.sum,
                                                'visual_pokemon_correct_block1': np.sum,
                                                'visual_pokemon_correct_block2': np.sum,
                                                'visual_animal_correct_block1': np.sum,
                                                'visual_animal_correct_block2': np.sum,
                                                'auditory_correct': np.sum,
                                                'auditory_correct_block1': np.sum,
                                                'auditory_correct_block2': np.sum,
                                                'pokemon_auditory_correct': np.sum,
                                                'animal_auditory_correct': np.sum,
                                                'auditory_pokemon_correct_block1': np.sum,
                                                'auditory_pokemon_correct_block2': np.sum,
                                                'auditory_animal_correct_block1': np.sum,
                                                'auditory_animal_correct_block2': np.sum,
                                                'pattern_comparison_correct': np.sum,
                                                'pattern_comparison_correct_block1': np.sum,
                                                'pattern_comparison_correct_block2': np.sum,
                                                'numberset_correct': np.sum,
                                                'letterset_correct': np.sum,
                                                'trivia_reaction_time': np.nanmean,
                                                'overall_visual_reaction_time': np.nanmean,
                                                'pokemon_visual_reaction_time': np.nanmean,
                                                'animal_visual_reaction_time': np.nanmean,
                                                'overall_auditory_reaction_time': np.nanmean,
                                                'pokemon_auditory_reaction_time': np.nanmean,
                                                'animal_auditory_reaction_time': np.nanmean
                                            }

for game in all_games_possible:
    if game == 'Alpha_Saphire':
        game = 'Alpha_Sapphire'
    elif game == "Let's_Go_Eevee":
        game = 'l_g_eevee'
    elif game == "Let's_Go_Pikachu":
        game = 'l_g_pikachu'
    elif game == "Scarlet":
        game = 'scarlett'
    agg_dict[game.lower()] = 'first'
    
df.columns = df.columns.str.lower()
    
grouped_df = df.groupby('participant_id').agg(agg_dict)

# %%
# Calculate the score on the real/fake Pokemon name task.
grouped_df['name_task_score'] = grouped_df['real_names_correct'] - grouped_df['fake_names_incorrect']

# %%
merged_grouped_df = pd.merge(grouped_df, expertise_df, on='participant_id', how='left').reset_index()

columns_to_combine = ['pokemon_interest', 'pokemon_knowledge',
                        'watched_movies_tv', 'movie_tv_multiple', 'movie_tv_number', 'age_first_movie',
                        'played_pokemon_games', 'played_multiple_times', 'played_number_times', 
                        'years_since_first_game', 'favorite_pokemon', 'fav_gen', 'follow_socials',
                        'engage_weekly', 'collect_trading_cards', 'years_collecting_cards',
                        'play_competitively', 'years_play_competitively']

for column in columns_to_combine:
    merged_grouped_df[column] = np.where((merged_grouped_df[column + '_x'] == None) \
                                         | (merged_grouped_df[column + '_x'] == np.nan) \
                                         | (merged_grouped_df[column + '_x'] == 'None'), 
                                         merged_grouped_df[column + '_y'], 
                                         merged_grouped_df[column + '_x'])
    merged_grouped_df.drop(columns = [column + '_x', column + '_y'], inplace=True)

# %%
for key, value in expertise_dict.items():
    
    for game in value:
        
        if game == 'Alpha_Saphire':
            game = 'Alpha_Sapphire'
        elif game == "Let's_Go_Eevee":
            game = 'l_g_eevee'
        elif game == "Let's_Go_Pikachu":
            game = 'l_g_pikachu'
        elif game == "Scarlet":
            game = 'scarlett'
        
        game = game.lower()
        
        merged_grouped_df[game] = np.where((merged_grouped_df['participant_id'] == key) \
                                           | (merged_grouped_df[game] == True) \
                                           | (merged_grouped_df[game] == 'TRUE'),
                                      True,
                                      False)

# %%
merged_grouped_df['numberset_correct'] = merged_grouped_df['numberset_correct'].apply(lambda x: float(x))
merged_grouped_df['letterset_correct'] = merged_grouped_df['letterset_correct'].apply(lambda x: float(x))
merged_grouped_df['name_task_score'] = merged_grouped_df['name_task_score'].apply(lambda x: float(x))

# %%
merged_grouped_df # might want to calculate how many of the games were played
# Out:
#     index  participant_id       gender   age    education real_names_correct  \
# 0       0           101.0     g_female  25.0    bachelors                 22
# 1       1           102.0  g_nonbinary  19.0  high_school                 12
# 2       2           104.0       g_male  20.0  high_school                 25
# 3       3           105.0     g_female  31.0    bachelors                 25
# 4       4           106.0       g_male  22.0  high_school                 25
# 5       5           107.0       g_male  55.0    bachelors                 22
# 6       6           108.0       g_male  31.0    bachelors                 25
# 7       7           109.0       g_male  22.0  high_school                 25
# 8       8           110.0     g_female  31.0    bachelors                 24
# 9       9           111.0     g_female  27.0    bachelors                 25
# 10     10           112.0       g_male  31.0  high_school                 25
# 11     11           113.0       g_male  26.0    bachelors                 25
# 12     12           114.0     g_female  26.0  high_school                 25
# 13     13           115.0       g_male  36.0    bachelors                 25
# 14     14           116.0  g_nonbinary  24.0  high_school                 22
# 15     15           117.0       g_male  46.0  high_school                 16
# 16     16           118.0       g_male  58.0          phd                  9
# 17     17           119.0     g_female  19.0  high_school                 25
# 18     18           120.0     g_female  28.0    bachelors                 25
# 19     19           121.0       g_male  24.0    bachelors                 25
# 20     20           122.0       g_male  23.0    bachelors                 25
# 21     21           123.0       g_male  18.0  high_school                 25
# 22     22           124.0       g_male  25.0    bachelors                 25
# 23     23           125.0       g_male  29.0      no_resp                 25
# 24     24           126.0       g_male  23.0  high_school                 25
# 25     25           127.0       g_male  33.0    bachelors                 25
# 26     26           128.0       g_male  34.0  high_school                 25
# 27     27           129.0       g_male  41.0  high_school                 25
# 28     28           130.0       g_male  33.0      no_resp                 25
# 29     29           131.0       g_male  28.0    bachelors                 25
# 30     30           132.0       g_male  26.0    bachelors                 25
# 31     31           133.0       g_male  29.0    bachelors                 25
# 32     32           134.0       g_male  32.0    bachelors                 23
# 33     33           135.0       g_male  36.0  high_school                 23
# 34     34           136.0       g_male  31.0  high_school                 24
# 35     35           137.0       g_male  36.0    bachelors                 24
# 36     36           138.0       g_male  28.0    bachelors                 25
# 37     37           139.0     g_female  29.0  high_school                 22
# 38     38           140.0       g_male  27.0    bachelors                 25
# 39     39           141.0     g_female  34.0    bachelors                 25
# 40     40           142.0       g_male  36.0    bachelors                 23
# 41     41           143.0       g_male  21.0  high_school                 25
# 42     42           144.0       g_male  41.0      masters                 24
# 43     43           145.0     g_female  34.0  high_school                  9
# 44     44           146.0       g_male  26.0    bachelors                 25
# 45     45           147.0       g_male  25.0  high_school                  4
# 46     46           148.0       g_male  26.0    bachelors                 25
# 47     47           150.0     g_female  33.0  high_school                 24
# 48     48           151.0       g_male  33.0  high_school                 25
# 49     49           152.0       g_male  26.0  high_school                 25
# 50     50           153.0       g_male  32.0      masters                 25
# 51     51           154.0       g_male  36.0  high_school                 24
# 52     52           155.0       g_male  32.0    bachelors                 25
# 53     53           157.0     g_female  24.0    bachelors                 25
# 54     54           158.0       g_male  25.0    bachelors                 25
# 55     55           159.0       g_male  35.0  high_school                 25
# 56     56           160.0       g_male  32.0    bachelors                 24
# 57     57           161.0       g_male  18.0  high_school                 24
# 58     58           162.0       g_male  30.0  high_school                 25
# 59     59           163.0       g_male  28.0  high_school                 25
# 60     60           164.0       g_male  28.0  high_school                 25
# 61     61           165.0     g_female  35.0  high_school                 25
# 62     62           166.0       g_male  37.0    bachelors                 20
# 63     63           169.0       g_male  25.0    bachelors                 25
# 64     64           170.0       g_male  26.0    bachelors                 25
# 65     65           171.0     g_female  27.0    bachelors                 22
# 66     66           172.0       g_male  25.0    bachelors                 25
# 67     67           173.0       g_male  32.0    bachelors                 25
# 68     68           174.0       g_male  27.0          phd                 25
# 69     69           175.0     g_female  30.0  high_school                 25
# 70     70           176.0       g_male  20.0  high_school                 25
# 71     71           177.0       g_male  20.0  high_school                 23
# 72     72           178.0       g_male  19.0  high_school                 19
# 73     73           179.0     g_female  18.0  high_school                 25
# 74     74           180.0     g_female  45.0      masters                 25
# 75     75           181.0       g_male  45.0          phd                  8
# 76     76           182.0     g_female  30.0  high_school                 23
# 77     77           183.0       g_male  30.0    bachelors                 25
# 78     78           184.0       g_male  26.0  high_school                 25
# 79     79           185.0       g_male  36.0  high_school                 25
# 80     80           186.0       g_male  27.0    bachelors                 25
# 81     81           187.0       g_male  26.0    bachelors                 25
# 82     82           188.0  g_nonbinary  20.0  high_school                 24
# 83     83           189.0       g_male  41.0          phd                 15
# 84     84           190.0       g_male  37.0    bachelors                 25
# 85     85           191.0       g_male  50.0  high_school                 24
# 86     86           193.0       g_male  22.0      masters                 24
# 87     87           194.0       g_male  40.0    bachelors                 24
# 88     88           195.0       g_male  20.0  high_school                 25
# 89     89           196.0  g_nonbinary  33.0    bachelors                 25
# 90     90           197.0  g_nonbinary  37.0    bachelors                 25
# 91     91           198.0       g_male  40.0  high_school                 25
# 92     92           199.0       g_male  19.0  high_school                 25
# 93     93           200.0       g_male  34.0  high_school                 25
# 94     94           201.0       g_male  23.0    bachelors                 25
# 95     95           202.0       g_male  34.0    bachelors                 25
# 96     96           203.0       g_male  34.0    bachelors                 24
#
#    fake_names_incorrect  trivia_correct  visual_correct  \
# 0                     2              15              91
# 1                     3              15              88
# 2                     0              25             100
# 3                     0              25              99
# 4                     0              20              97
# 5                     5              18              96
# 6                     0              24              99
# 7                     1              20              99
# 8                     0              17             100
# 9                     0              15              98
# 10                    0              24              98
# 11                    0              25             100
# 12                    0              25             100
# 13                    0              25              99
# 14                    0              22              98
# 15                    0              18              86
# 16                    2              10              50
# 17                    0              20              98
# 18                    1              21              99
# 19                    0              24              98
# 20                    0              25              99
# 21                    0              25             100
# 22                    0              25             100
# 23                    0              25             100
# 24                    3              25             100
# 25                    7              24              99
# 26                    1              24             100
# 27                    0              25              98
# 28                    0              25              97
# 29                    0              25             100
# 30                    0              24              99
# 31                    0              25              98
# 32                    1              25             100
# 33                    0              25             100
# 34                    1              23              97
# 35                    0              25             100
# 36                    0              22              98
# 37                    1              21             100
# 38                    0              25             100
# 39                    0              25              99
# 40                    0              25             100
# 41                    0              23             100
# 42                    0              25             100
# 43                    0              10              64
# 44                    0              22              99
# 45                    0              15              63
# 46                    0              25             100
# 47                    3              14              98
# 48                    0              25             100
# 49                    0              25             100
# 50                    0              25             100
# 51                    0              24              99
# 52                    0              25             100
# 53                    1              21              99
# 54                    0              25             100
# 55                    0              24              98
# 56                    0              23              99
# 57                    1              22             100
# 58                    1              25              99
# 59                    4              25              95
# 60                    2              22             100
# 61                    0              20              99
# 62                    0              15              93
# 63                    0              24              98
# 64                    0              25              99
# 65                    0              18              97
# 66                    0              24             100
# 67                    0              25              98
# 68                    0              21             100
# 69                    0              25             100
# 70                    0              25             100
# 71                    0              21              97
# 72                    3              16              93
# 73                    0              25             100
# 74                    1              15             100
# 75                    0              12              73
# 76                    0              20              99
# 77                    7              24              99
# 78                    2              24              99
# 79                    3              21              98
# 80                    4              19             100
# 81                    0              24             100
# 82                    1              25             100
# 83                    1              17              89
# 84                    1              23             100
# 85                    3              20              99
# 86                    3              24              98
# 87                    0              25              99
# 88                    0              25             100
# 89                    2              24             100
# 90                    0              23             100
# 91                    0              25              99
# 92                    0              25              99
# 93                    0              21              99
# 94                    2              25              98
# 95                    0              25             100
# 96                    0              25             100
#
#     visual_correct_block1  visual_correct_block2  pokemon_visual_correct  \
# 0                    47.0                   44.0                    71.0
# 1                    41.0                   47.0                    68.0
# 2                    50.0                   50.0                    80.0
# 3                    50.0                   49.0                    79.0
# 4                    49.0                   48.0                    77.0
# 5                    50.0                   46.0                    78.0
# 6                    49.0                   50.0                    79.0
# 7                    49.0                   50.0                    79.0
# 8                    50.0                   50.0                    80.0
# 9                    50.0                   48.0                    79.0
# 10                   50.0                   48.0                    78.0
# 11                   50.0                   50.0                    80.0
# 12                   50.0                   50.0                    80.0
# 13                   49.0                   50.0                    80.0
# 14                   49.0                   49.0                    78.0
# 15                   43.0                   43.0                    66.0
# 16                   26.0                   24.0                    31.0
# 20             None    None                None           NaN
# 21             None    None                None           NaN
# 22             None    None                None           NaN
# 23             None    None                None           NaN
# 24             None    None                None           NaN
# 25             None    None                None           NaN
# 26             None    None                None           NaN
# 27             None    None                None           NaN
# 28             None    None                None           NaN
# 29             None    None                None           NaN
# 30             None    None                None           NaN
# 31             None    None                None           NaN
# 32             None    None                None           NaN
# 33             None    None                None           NaN
# 34             None    None                None           NaN
# 35             None    None                None           NaN
# 36             None    None                None           NaN
# 37             None    None                None           NaN
# 38             None    None                None           NaN
# 39             None    None                None           NaN
# 40             None    None                None           NaN
# 41             None    None                None           NaN
# 42             None    None                None           NaN
# 43             None    None                None           NaN
# 44             None    None                None           NaN
# 45             None    None                None           NaN
# 46             None    None                None           NaN
# 47             None    None                None           NaN
# 48             None    None                None           NaN
# 49             None    None                None           NaN
# 50             None    None                None           NaN
# 51             None    None                None           NaN
# 52             None    None                None           NaN
# 53             None    None                None           NaN
# 54             None    None                None           NaN
# 55             None    None                None           NaN
# 56             None    None                None           NaN
# 57             None    None                None           NaN
# 58             None    None                None           NaN
# 59             None    None                None           NaN
# 60             None    None                None           NaN
# 61             None    None                None           NaN
# 62             None    None                None           NaN
# 63             None    None                None           NaN
# 64             None    None                None           NaN
# 65             None    None                None           NaN
# 66             None    None                None           NaN
# 67             None    None                None           NaN
# 68             None    None                None           NaN
# 69             None    None                None           NaN
# 70             None    None                None           NaN
# 71          turtwig     5.0  follow_socials_yes           4.0
# 72         charzard   gen 1  follow_socials_yes           4.0
# 73          Darkrai     5.0   follow_socials_no           2.0
# 74          Gyrados    Hohn   follow_socials_no          20.0
# 75             None    None   follow_socials_no           0.0
# 76            Eevee     2.0  follow_socials_yes           4.0
# 77        Dunsparce   Gen 2   follow_socials_no           4.0
# 78           Zapdos   Unova   follow_socials_no           1.0
# 79           Mewtwo   First   follow_socials_no           2.0
# 80        Dragonite   Gen 1   follow_socials_no           0.0
# 81      Jiggilypuff     3.0   follow_socials_no           0.0
# 82             None   Gen 5  follow_socials_yes          48.0
# 83         Mincinno    None   follow_socials_no           1.0
# 84        Dragonair     1st   follow_socials_no           2.0
# 85           Mewtwo   Gen 9  follow_socials_yes          21.0
# 86          Lucario     5.0   follow_socials_no           0.0
# 87          umbreon     2.0   follow_socials_no           0.0
# 88           Piplup   Gen 6  follow_socials_yes           5.0
# 89           wooloo     2.0   follow_socials_no           1.0
# 90           gengar     2.0   follow_socials_no           1.0
# 91       Typhlosion     7.0  follow_socials_yes           5.0
# 92          Noivern     3.0  follow_socials_yes           4.0
# 93           Tauros     1.0  follow_socials_yes           3.0
# 94       Charmander   Gen 1  follow_socials_yes          10.0
# 95          Snorlax   First  follow_socials_yes           1.0
# 96         Nidoking     2nd  follow_socials_yes           8.0
#
#         collect_trading_cards years_collecting_cards      play_competitively  \
# 0                        None                    NaN                    None
# 1                        None                    NaN                    None
# 2                        None                    NaN                    None
# 3                        None                    NaN                    None
# 4                        None                    NaN                    None
# 5                        None                    NaN                    None
# 6                        None                    NaN                    None
# 7                        None                    NaN                    None
# 8                        None                    NaN                    None
# 9                        None                    NaN                    None
# 10                       None                    NaN                    None
# 11                       None                    NaN                    None
# 12                       None                    NaN                    None
# 13                       None                    NaN                    None
# 14                       None                    NaN                    None
# 15                       None                    NaN                    None
# 16                       None                    NaN                    None
# 17                       None                    NaN                    None
# 18                       None                    NaN                    None
# 19                       None                    NaN                    None
# 20                       None                    NaN                    None
# 21                       None                    NaN                    None
# 22                       None                    NaN                    None
# 23                       None                    NaN                    None
# 24                       None                    NaN                    None
# 25                       None                    NaN                    None
# 26                       None                    NaN                    None
# 27                       None                    NaN                    None
# 28                       None                    NaN                    None
# 29                       None                    NaN                    None
# 30                       None                    NaN                    None
# 31                       None                    NaN                    None
# 32                       None                    NaN                    None
# 33                       None                    NaN                    None
# 34                       None                    NaN                    None
# 35                       None                    NaN                    None
# 36                       None                    NaN                    None
# 37                       None                    NaN                    None
# 38                       None                    NaN                    None
# 39                       None                    NaN                    None
# 40                       None                    NaN                    None
# 41                       None                    NaN                    None
# 42                       None                    NaN                    None
# 43                       None                    NaN                    None
# 44                       None                    NaN                    None
# 45                       None                    NaN                    None
# 46                       None                    NaN                    None
# 47                       None                    NaN                    None
# 48                       None                    NaN                    None
# 49                       None                    NaN                    None
# 50                       None                    NaN                    None
# 51                       None                    NaN                    None
# 52                       None                    NaN                    None
# 53                       None                    NaN                    None
# 54                       None                    NaN                    None
# 55                       None                    NaN                    None
# 56                       None                    NaN                    None
# 57                       None                    NaN                    None
# 58                       None                    NaN                    None
# 59                       None                    NaN                    None
# 60                       None                    NaN                    None
# 61                       None                    NaN                    None
# 62                       None                    NaN                    None
# 63                       None                    NaN                    None
# 64                       None                    NaN                    None
# 65                       None                    NaN                    None
# 66                       None                    NaN                    None
# 67                       None                    NaN                    None
# 68                       None                    NaN                    None
# 69                       None                    NaN                    None
# 70                       None                    NaN                    None
# 71  collect_trading_cards_yes                   10.0   play_competitively_no
# 72   collect_trading_cards_no                    8.0   play_competitively_no
# 73   collect_trading_cards_no                   10.0   play_competitively_no
# 74  collect_trading_cards_yes                    5.0   play_competitively_no
# 75   collect_trading_cards_no                    NaN   play_competitively_no
# 76  collect_trading_cards_yes                   20.0   play_competitively_no
# 77  collect_trading_cards_yes                   20.0   play_competitively_no
# 78   collect_trading_cards_no                   15.0   play_competitively_no
# 79   collect_trading_cards_no                   26.0   play_competitively_no
# 80  collect_trading_cards_yes                    4.0   play_competitively_no
# 81  collect_trading_cards_yes                   18.0   play_competitively_no
# 82   collect_trading_cards_no                    NaN   play_competitively_no
# 83  collect_trading_cards_yes                    2.0   play_competitively_no
# 84  collect_trading_cards_yes                   27.0   play_competitively_no
# 85  collect_trading_cards_yes                    2.0   play_competitively_no
# 86   collect_trading_cards_no                   16.0   play_competitively_no
# 87   collect_trading_cards_no                    0.0   play_competitively_no
# 88  collect_trading_cards_yes                    1.0   play_competitively_no
# 89   collect_trading_cards_no                   24.0   play_competitively_no
# 90   collect_trading_cards_no                    NaN   play_competitively_no
# 91   collect_trading_cards_no                   15.0   play_competitively_no
# 92   collect_trading_cards_no                    NaN  play_competitively_yes
# 93  collect_trading_cards_yes                   22.0   play_competitively_no
# 94  collect_trading_cards_yes                   16.0   play_competitively_no
# 95  collect_trading_cards_yes                   27.0   play_competitively_no
# 96  collect_trading_cards_yes                   25.0  play_competitively_yes
#
#    years_play_competitively
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 25                      NaN
# 26                      NaN
# 27                      NaN
# 28                      NaN
# 29                      NaN
# 30                      NaN
# 31                      NaN
# 32                      NaN
# 33                      NaN
# 34                      NaN
# 35                      NaN
# 36                      NaN
# 37                      NaN
# 38                      NaN
# 39                      NaN
# 40                      NaN
# 41                      NaN
# 42                      NaN
# 43                      NaN
# 44                      NaN
# 45                      NaN
# 46                      NaN
# 47                      NaN
# 48                      NaN
# 49                      NaN
# 50                      NaN
# 51                      NaN
# 52                      NaN
# 53                      NaN
# 54                      NaN
# 55                      NaN
# 56                      NaN
# 57                      NaN
# 58                      NaN
# 59                      NaN
# 60                      NaN
# 61                      NaN
# 62                      NaN
# 63                      NaN
# 64                      NaN
# 65                      NaN
# 66                      NaN
# 67                      NaN
# 68                      NaN
# 69                      NaN
# 70                      NaN
# 71                      NaN
# 72                      0.0
# 73                      NaN
# 74                      0.0
# 75                      NaN
# 76                      0.0
# 77                      NaN
# 78                      NaN
# 79                      NaN
# 80                      0.0
# 81                      0.0
# 82                      NaN
# 83                      NaN
# 84                      NaN
# 85                      NaN
# 86                      0.0
# 87                      0.0
# 88                      NaN
# 89                      NaN
# 90                      NaN
# 91                      NaN
# 92                      5.0
# 93                      0.0
# 94                      0.0
# 95                      0.0
# 96                      3.0

# %%
# merged_grouped_df.to_csv('cleaned_pokemon_data.csv')

# %% [markdown]
# ## Check means, SD, max, and min of each task to make sure they are in bound

# %%
merged_grouped_df.describe()
# Out:
#            index  participant_id        age  trivia_correct  visual_correct  \
# count  97.000000       97.000000  97.000000       97.000000       97.000000
# mean   48.000000      151.762887  29.969072       22.278351       97.030928
# std    28.145456       30.024217   7.881219        3.757610        7.805518
# min     0.000000      101.000000  18.000000       10.000000       50.000000
# 25%    24.000000      126.000000  25.000000       21.000000       98.000000
# 50%    48.000000      151.000000  29.000000       24.000000       99.000000
# 75%    72.000000      178.000000  34.000000       25.000000      100.000000
# max    96.000000      203.000000  58.000000       25.000000      100.000000
#
#        visual_correct_block1  visual_correct_block2  pokemon_visual_correct  \
# count              97.000000              97.000000               97.000000
# mean               48.577320              48.453608               77.237113
# std                 3.807435               4.198265                7.761783
# min                26.000000              24.000000               31.000000
# 25%                49.000000              49.000000               78.000000
# 50%                50.000000              50.000000               79.000000
# 75%                50.000000              50.000000               80.000000
# max                50.000000              50.000000               80.000000
#
#        animal_visual_correct  visual_pokemon_correct_block1  \
# count              97.000000                      97.000000
# mean               19.793814                      38.680412
# std                 0.477366                       3.798427
# min                18.000000                      16.000000
# 25%                20.000000                      39.000000
# 50%                20.000000                      40.000000
# 75%                20.000000                      40.000000
# max                20.000000                      40.000000
#
#        visual_pokemon_correct_block2  visual_animal_correct_block1  \
# count                      97.000000                     97.000000
# mean                       38.556701                      9.896907
# std                         4.138158                      0.338025
# min                        15.000000                      8.000000
# 25%                        39.000000                     10.000000
# 50%                        40.000000                     10.000000
# 75%                        40.000000                     10.000000
# max                        40.000000                     10.000000
#
#        visual_animal_correct_block2  auditory_correct  \
# count                     97.000000         97.000000
# mean                       9.896907         47.515464
# std                        0.367552         18.722821
# min                        8.000000         21.000000
# 25%                       10.000000         33.000000
# 50%                       10.000000         41.000000
# 75%                       10.000000         55.000000
# max                       10.000000         96.000000
#
#        auditory_correct_block1  auditory_correct_block2  \
# count                97.000000                97.000000
# mean                 24.391753                23.123711
# std                   9.496224                 9.648249
# min                  11.000000                 9.000000
# 25%                  18.000000                16.000000
# 50%                  20.000000                21.000000
# 75%                  30.000000                27.000000
# max                  48.000000                49.000000
#
#        pokemon_auditory_correct  animal_auditory_correct  \
# count                 97.000000                97.000000
# mean                  29.701031                17.814433
# std                   18.056142                 1.975527
# min                    7.000000                 8.000000
# 25%                   17.000000                17.000000
# 50%                   22.000000                18.000000
# 75%                   36.000000                19.000000
# max                   77.000000                20.000000
#
#        auditory_pokemon_correct_block1  auditory_pokemon_correct_block2  \
# count                        97.000000                        97.000000
# mean                         15.463918                        14.237113
# std                           9.209440                         9.213637
# min                           3.000000                         3.000000
# 25%                           9.000000                         7.000000
# 50%                          12.000000                        11.000000
# 75%                          20.000000                        17.000000
# max                          39.000000                        39.000000
#
#        auditory_animal_correct_block1  auditory_animal_correct_block2  \
# count                       97.000000                       97.000000
# mean                         8.927835                        8.886598
# std                          1.012911                        1.329758
# min                          5.000000                        3.000000
# 25%                          8.000000                        8.000000
# 50%                          9.000000                        9.000000
# 75%                         10.000000                       10.000000
# max                         10.000000                       10.000000
#
#        pattern_comparison_correct  pattern_comparison_correct_block1  \
# count                   97.000000                          97.000000
# mean                    24.226804                          11.835052
# std                      3.906472                           2.361499
# min                     14.000000                           3.000000
# 25%                     22.000000                          10.000000
# 50%                     25.000000                          12.000000
# 75%                     27.000000                          13.000000
# max                     33.000000                          18.000000
#
#        pattern_comparison_correct_block2  numberset_correct  \
# count                          97.000000          97.000000
# mean                           12.391753           8.649485
# std                             2.369760           3.421870
# min                             4.000000           2.000000
# 25%                            11.000000           7.000000
# 50%                            13.000000           9.000000
# 75%                            14.000000          11.000000
# max                            16.000000          15.000000
#
#        letterset_correct  trivia_reaction_time  overall_visual_reaction_time  \
# count          97.000000             97.000000                     97.000000
# mean            9.164948              5.279318                      1.605351
# std             3.504998              1.577309                      0.356960
# min             2.000000              2.958160                      1.089240
# 25%             6.000000              4.038086                      1.364140
# 50%             9.000000              4.835264                      1.537678
# 75%            12.000000              5.966296                      1.736511
# max            17.000000             10.420001                      3.047943
#
#        pokemon_visual_reaction_time  animal_visual_reaction_time  \
# count                     97.000000                    97.000000
# mean                       1.657787                     1.427143
# std                        0.436598                     0.250072
# min                        1.086916                     0.968575
# 25%                        1.371822                     1.269857
# 50%                        1.536339                     1.382250
# 75%                        1.832663                     1.513589
# max                        3.701865                     2.568260
#
#        overall_auditory_reaction_time  pokemon_auditory_reaction_time  \
# count                       97.000000                       97.000000
# mean                         2.668894                        3.069072
# std                          0.744838                        1.111454
# min                          1.404891                        0.874147
# 25%                          2.097306                        2.262975
# 50%                          2.629861                        3.027448
# 75%                          3.121300                        3.908097
# max                          4.739716                        5.580900
#
#        animal_auditory_reaction_time  name_task_score
# count                      97.000000        97.000000
# mean                        2.024339        22.690722
# std                         0.439980         4.260675
# min                         1.332513         4.000000
# 25%                         1.704170        23.000000
# 50%                         1.916366        24.000000
# 75%                         2.231800        25.000000
# max                         3.598125        25.000000

# %% [markdown]
# ## Convert all predictor measures (scores) to z scores; for each measure, identify values > |3.5| from total sample mean; replace outliers with z = +/- 3.5.

# %%
for task in ['trivia_correct', 
                  'name_task_score',
                  'pattern_comparison_correct', 
                  'numberset_correct', 
                  'letterset_correct']:
    merged_grouped_df[task + '_zscore'] = merged_grouped_df[[task]].apply(zscore)
    
    merged_grouped_df[task + '_zscore'] = np.where((merged_grouped_df[task + '_zscore'] > 3.5),
                                                   3.5,
                                                   merged_grouped_df[task + '_zscore']
                                                  )
    merged_grouped_df[task + '_zscore'] = np.where((merged_grouped_df[task + '_zscore'] < -3.5),
                                                   -3.5,
                                                   merged_grouped_df[task + '_zscore']
                                                  )

# %%
merged_grouped_df[['trivia_correct_zscore', 
                  'name_task_score_zscore',
                  'pattern_comparison_correct_zscore', 
                  'numberset_correct_zscore', 
                  'letterset_correct_zscore']]
# Out:
#     trivia_correct_zscore  name_task_score_zscore  \
# 0               -1.947025               -0.634805
# 1               -1.947025               -3.229968
# 2                0.728066                0.544814
# 3                0.728066                0.544814
# 4               -0.609480                0.544814
# 5               -1.144498               -1.342577
# 6                0.460557                0.544814
# 7               -0.609480                0.308890
# 8               -1.412007                0.308890
# 9               -1.947025                0.544814
# 10               0.460557                0.544814
# 11               0.728066                0.544814
# 12               0.728066                0.544814
# 13               0.728066                0.544814
# 14              -0.074461               -0.162958
# 15              -1.144498               -1.578501
# 16              -3.284571               -3.500000
# 17              -0.609480                0.544814
# 18              -0.341970                0.308890
# 19               0.460557                0.544814
# 20               0.728066                0.544814
# 21               0.728066                0.544814
# 22               0.728066                0.544814
# 23               0.728066                0.544814
# 24               0.728066               -0.162958
# 25               0.460557               -1.106653
# 26               0.460557                0.308890
# 27               0.728066                0.544814
# 28               0.728066                0.544814
# 29               0.728066                0.544814
# 30               0.460557                0.544814
# 31               0.728066                0.544814
# 32               0.728066               -0.162958
# 33               0.728066                0.072966
# 34               0.193048                0.072966
# 35               0.728066                0.308890
# 36              -0.074461                0.544814
# 37              -0.341970               -0.398882
# 38               0.728066                0.544814
# 39               0.728066                0.544814
# 40               0.728066                0.072966
# 41               0.193048                0.544814
# 42               0.728066                0.308890
# 43              -3.284571               -3.229968
# 44              -0.074461                0.544814
# 45              -1.947025               -3.500000
# 46               0.728066                0.544814
# 47              -2.214534               -0.398882
# 48               0.728066                0.544814
# 49               0.728066                0.544814
# 50               0.728066                0.544814
# 51               0.460557                0.308890
# 52               0.728066                0.544814
# 53              -0.341970                0.308890
# 54               0.728066                0.544814
# 55               0.460557                0.544814
# 56               0.193048                0.308890
# 57              -0.074461                0.072966
# 58               0.728066                0.308890
# 59               0.728066               -0.398882
# 60              -0.074461                0.072966
# 61              -0.609480                0.544814
# 62              -1.947025               -0.634805
# 63               0.460557                0.544814
# 64               0.728066                0.544814
# 65              -1.144498               -0.162958
# 66               0.460557                0.544814
# 67               0.728066                0.544814
# 68              -0.341970                0.544814
# 69               0.728066                0.544814
# 70               0.728066                0.544814
# 71              -0.341970                0.072966
# 72              -1.679516               -1.578501
# 73               0.728066                0.544814
# 74              -1.947025                0.308890
# 75              -2.749552               -3.465892
# 76              -0.609480                0.072966
# 77               0.460557               -1.106653
# 78               0.460557                0.072966
# 79              -0.341970               -0.162958
# 80              -0.876989               -0.398882
# 81               0.460557                0.544814
# 82               0.728066                0.072966
# 83              -1.412007               -2.050349
# 84               0.193048                0.308890
# 85              -0.609480               -0.398882
# 86               0.460557               -0.398882
# 87               0.728066                0.308890
# 88               0.728066                0.544814
# 89               0.460557                0.072966
# 90               0.193048                0.544814
# 91               0.728066                0.544814
# 92               0.728066                0.544814
# 93              -0.341970                0.544814
# 94               0.728066                0.072966
# 95               0.728066                0.544814
# 96               0.728066                0.308890
#
#     pattern_comparison_correct_zscore  numberset_correct_zscore  \
# 0                           -0.315675                 -1.072058
# 1                           -0.830306                 -1.953326
# 2                           -0.058360                  0.396722
# 3                           -1.344936                  0.396722
# 4                            0.970901                 -0.190790
# 5                           -0.315675                 -0.484546
# 6                            1.228216                  0.102966
# 7                            0.713586                 -1.072058
# 8                           -1.859567                 -1.072058
# 9                           -0.572991                  0.102966
# 10                          -2.631513                  0.690478
# 11                          -2.374197                  0.102966
# 12                          -1.087621                 -0.190790
# 13                           0.713586                  0.396722
# 14                          -0.058360                  0.102966
# 15                          -1.859567                 -0.190790
# 16                          -1.087621                  0.396722
# 17                          -0.572991                 -0.484546
# 18                           0.456270                 -0.484546
# 19                          -0.058360                 -0.484546
# 20                           1.228216                  0.984234
# 21                          -0.058360                  0.690478
# 22                          -0.830306                 -1.365814
# 23                           2.257477                  0.102966
# 24                           0.713586                 -0.484546
# 25                           0.456270                 -0.484546
# 26                          -0.830306                 -0.778302
# 27                          -0.058360                  1.571746
# 28                          -0.058360                  1.571746
# 29                           0.713586                  1.865502
# 30                          -0.830306                 -1.365814
# 31                           0.970901                 -0.484546
# 32                           0.970901                  1.277990
# 33                          -2.116882                 -1.659570
# 34                          -1.602252                 -1.659570
# 35                          -1.087621                 -1.072058
# 36                           0.198955                 -0.190790
# 37                           1.228216                 -1.365814
# 38                           1.485531                 -0.190790
# 39                           0.198955                  0.102966
# 40                          -0.058360                 -0.484546
# 41                           1.485531                  1.277990
# 54                  1.386640
# 55                 -1.194461
# 56                 -0.907672
# 57                 -0.907672
# 58                 -1.194461
# 59                 -0.334094
# 60                 -0.620883
# 61                  0.813062
# 62                 -0.334094
# 63                  0.813062
# 64                 -0.907672
# 65                  0.813062
# 66                  1.386640
# 67                  0.526273
# 68                  0.239484
# 69                 -0.620883
# 70                  1.386640
# 71                 -0.907672
# 72                 -0.620883
# 73                  1.099851
# 74                  1.386640
# 75                  0.526273
# 76                  0.526273
# 77                 -1.194461
# 78                 -1.194461
# 79                 -0.620883
# 80                 -0.907672
# 81                 -0.334094
# 82                 -0.620883
# 83                  0.813062
# 84                  1.099851
# 85                  0.239484
# 86                 -0.047305
# 87                  2.247007
# 88                  1.099851
# 89                 -0.047305
# 90                 -0.620883
# 91                 -0.334094
# 92                  1.673429
# 93                  1.099851
# 94                 -0.334094
# 95                 -0.334094
# 96                  0.526273

# %% [markdown]
# ## Compute zero-order correlations among all z predictor measures; assuming all measures correlate as expected (i.e., positive rs between Pokémon measures, Gf measures), create predictor composites by taking average of z scores for measures of each factor.

# %%
corr_matrix = merged_grouped_df[['trivia_correct_zscore', 
                                  'name_task_score_zscore',
                                  'pattern_comparison_correct_zscore', 
                                  'numberset_correct_zscore', 
                                  'letterset_correct_zscore',
                                   'auditory_correct',
                                   'visual_correct',
                                   'animal_visual_correct',
                                   'pokemon_visual_correct',
                                   'animal_auditory_correct',
                                   'pokemon_auditory_correct'
                                  ]].corr()

# %%
mask = np.zeros_like(corr_matrix, dtype=bool)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(10, 8))

sns.heatmap(
    corr_matrix,
    mask=mask,          
    cmap='coolwarm',  
    vmax=1,            
    vmin=-1,          
    center=0,          
    square=True,      
    linewidths=.5,     
    cbar_kws={"shrink": .5},
    annot=True,        
    fmt='.2f'           
)

plt.title('Lower Triangle Correlation Heatmap')
plt.show()

# %%
merged_grouped_df['pokemon_knowledge_composite_zscore'] = (merged_grouped_df['trivia_correct_zscore'] \
                                                           + merged_grouped_df['name_task_score_zscore']) / 2

# %%
merged_grouped_df['gf_composite_zscore'] = (merged_grouped_df['numberset_correct_zscore'] \
                                            + merged_grouped_df['letterset_correct_zscore']) / 2

# %% [markdown]
# ## Create interaction terms by multiplying Pokémon knowledge composite by Gf composite; and Pokémon knowledge composite by pattern comparison (z).
# PKxGf = PK z comp x Gf z comp
#
# PKxPC = PK z comp x PC z

# %%
merged_grouped_df['PKxGf'] = merged_grouped_df['pokemon_knowledge_composite_zscore'] * \
                             merged_grouped_df['gf_composite_zscore']
merged_grouped_df['PKxPC'] = merged_grouped_df['pokemon_knowledge_composite_zscore'] * \
                             merged_grouped_df['pattern_comparison_correct_zscore']

# %%
merged_grouped_df.to_csv('cleaned_df_for_jasp_new.csv')

# %% [markdown]
# ## For criterion measures (RT, accuracy for Pokémon and Animals recognition tasks), screen for outliers and replace outliers with +/- 3.5 raw score cutoff value (don’t z-transform, so that results can be interpreted in original units…or you could also z transform and then back-transform to original units).
# Not sure whether we want to create composites for criterion tasks…we can figure this out later
